# %% [markdown]
# <a href="https://colab.research.google.com/github/aasthadawar02/TME_6015/blob/main/Project_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Group Project Code**
#
# ```
# # Authoured by: Wasim Dawood Shaik, Aastha Dawar
# # UNB ID: 3744476, 3737216
# # Date: 29-11-2023
# ```

# %% [markdown]
# **Import Libraries**

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU
from keras.layers import Dropout
from keras.models import load_model
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import itertools
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %% [markdown]
# **Mounting Google Drive in Google Colab**

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Dataset selection**

# %%
dataframe = pd.read_csv("/content/drive/MyDrive/TME_6015/Project/BTC-USD.csv")

# %% [markdown]
# **Dataset Info**

# %% [markdown]
# [Bitcoin-USD datset download source](https://finance.yahoo.com/quote/BTC-USD/history?period1=1410825600&period2=1700956800&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true)
#
# *https://finance.yahoo.com/quote/BTC-USD/history?period1=1410825600&period2=1700956800&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true*

# %% [markdown]
# **Exploratory Data Analysis**

# %%
dataframe.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#        Volume
# 0  21056800.0
# 1  34483200.0
# 2  37919700.0
# 3  36863600.0
# 4  26580100.0

# %%
dataframe.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 3352  2023-11-21  37469.16016  37631.14063  35813.81250  35813.81250
# 3353  2023-11-22  35756.55469  37856.98047  35670.97266  37432.33984
# 3354  2023-11-23  37420.43359  37643.91797  36923.86328  37289.62109
# 3355  2023-11-24  37296.31641  38415.33984  37261.60547  37720.28125
# 3356  2023-11-25  37721.41406  37892.42969  37617.41797  37796.79297
#
#         Adj Close        Volume
# 3352  35813.81250  2.517216e+10
# 3353  37432.33984  2.439725e+10
# 3354  37289.62109  1.421495e+10
# 3355  37720.28125  2.292296e+10
# 3356  37796.79297  9.099571e+09

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3357 entries, 0 to 3356
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3357 non-null   object
#  1   Open       3357 non-null   float64
#  2   High       3357 non-null   float64
#  3   Low        3357 non-null   float64
#  4   Close      3357 non-null   float64
#  5   Adj Close  3357 non-null   float64
#  6   Volume     3357 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 183.7+ KB

# %%
dataframe.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   3357.000000   3357.000000   3357.000000   3357.000000   3357.000000
# mean   14280.733942  14617.408292  13917.086255  14290.522958  14290.522958
# std    16024.100730  16413.765412  15585.277279  16024.424885  16024.424885
# min      176.897003    211.731003    171.509995    178.102997    178.102997
# 25%      898.171997    913.184021    879.807007    899.072998    899.072998
# 50%     8169.060059   8296.694336   7944.776855   8180.479980   8180.479980
# 75%    23150.929690  23578.650390  22747.835940  23164.318360  23164.318360
# max    67549.734380  68789.625000  66382.062500  67566.828130  67566.828130
#
#              Volume
# count  3.357000e+03
# mean   1.648368e+10
# std    1.916332e+10
# min    5.914570e+06
# 25%    1.477750e+08
# 50%    1.100281e+10
# 75%    2.689636e+10
# max    3.509680e+11

# %%
dataframe.columns.tolist()
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %%
dataframe.shape
# Out:
# (3357, 7)

# %%
print(f"Columns : {dataframe.shape[1]} || Rows : {dataframe.shape[0]}")
# Out:
# Columns : 7 || Rows : 3357

# %%
na_values = dataframe.isna().values.sum()
null_values = dataframe.isnull().values.sum()
print(f"NA Values : {na_values} || Null Values : {null_values}")
# Out:
# NA Values : 0 || Null Values : 0

# %%
print(f"Dataset -> Start Date : {dataframe.iloc[0,0]} || End Date : {dataframe.iloc[-1,0]}")
# Out:
# Dataset -> Start Date : 2014-09-17 || End Date : 2023-11-25

# %%
dataframe['Date'] = pd.to_datetime(dataframe['Date'])

# %% [markdown]
# **Dataset Plotting**

# %%
plt.figure(figsize=(14,6), dpi= 100, facecolor='w', edgecolor='k')

plt.plot(dataframe['Date'], dataframe['Open'], color='red', label = 'Opening Price')
plt.plot(dataframe['Date'], dataframe['Close'], color='green', label = 'Closing Price')
plt.plot(dataframe['Date'], dataframe['Low'], color='black', label = 'Low Price')
plt.plot(dataframe['Date'], dataframe['High'], color='blue', label = 'High Price')
plt.xlabel('Date')
plt.ylabel('USD')
plt.legend(loc='best')
plt.title('Bitcoin Prices FY 2014-2023')

plt.subplots(2, 2, figsize = (14, 10))

ax1 = plt.subplot(2, 2, 1)
plt.plot(dataframe['Date'], dataframe['Open'], color='red', label = 'Opening Price')
plt.xlabel('Date')
plt.ylabel('Opening Price')
plt.title('Bitcoin Opening Prices FY 2014-2023')
plt.legend(loc='best')

ax2 = plt.subplot(2, 2, 2)
plt.plot(dataframe['Date'], dataframe['Close'], color='green', label = 'Closing Price')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Bitcoin Closing Prices FY 2014-2023')
plt.legend(loc='best')

ax3 = plt.subplot(2, 2, 3)
plt.plot(dataframe['Date'], dataframe['Low'], color='black', label = 'Low Price')
plt.xlabel('Date')
plt.ylabel('Low Price')
plt.title('Bitcoin Low Prices FY 2014-2023')
plt.legend(loc='best')

ax4 = plt.subplot(2, 2, 4)
plt.plot(dataframe['Date'], dataframe['High'], color='blue', label = 'High Price')
plt.xlabel('Date')
plt.ylabel('High Price')
plt.title('Bitcoin High Prices FY 2014-2023')
plt.legend(loc='best')

plt.show()

# %% [markdown]
# **Data Pre-processing**

# %%
final_dataframe = dataframe.drop(['Date','Open', 'Low', 'High','Adj Close'], axis=1)

# %%
final_dataframe.head()
# Out:
#         Close      Volume
# 0  457.334015  21056800.0
# 1  424.440002  34483200.0
# 2  394.795990  37919700.0
# 3  408.903992  36863600.0
# 4  398.821014  26580100.0

# %% [markdown]
# **Min-Max Scaler**

# %%
scalar = MinMaxScaler(feature_range=(0, 1))
dataframe_scaled = scalar.fit_transform(final_dataframe)

# %%
dataframe_scaled.shape
# Out:
# (3357, 2)

# %%
dataframe_scaled[0,:]
# Out:
# array([4.14358659e-03, 4.31449169e-05])

# %%
def create_train_test_dataset(dataframe, past_values = 1, train_test_split = 0):
  data_x, data_y = [], []
  for i in range(len(dataframe)-past_values):
    data_x.append(dataframe[i:i+past_values,:])
    data_y.append(dataframe[i+past_values:i+past_values+1,0])
  # print(len(data_x),len(data_y))
  split_index = int(round(train_test_split * len(dataframe)))
  x_train, x_test = data_x[:split_index], data_x[split_index:]
  y_train, y_test = data_y[:split_index], data_y[split_index:]
  return np.array(data_x), np.array(data_y), np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test)

# %%
data_x, data_y, x_train, y_train, x_test, y_test = create_train_test_dataset(dataframe_scaled, 25, 0.8)

# %%
x_train.shape, y_train.shape
# Out:
# ((2686, 25, 2), (2686, 1))

# %%
x_test.shape, y_test.shape
# Out:
# ((646, 25, 2), (646, 1))

# %% [markdown]
# **Model Selection**

# %% [markdown]
# **Model Summary**

# %%
model = Sequential()
model.add(LSTM(units=16, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2]), activation = "relu"))
model.add(Dropout(0.2))
model.add(LSTM(units=16, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1, activation='linear'))
model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 25, 16)            1216
#
#  dropout (Dropout)           (None, 25, 16)            0
#
#  lstm_1 (LSTM)               (None, 16)                2112
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 3345 (13.07 KB)
# Trainable params: 3345 (13.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Model Training**

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

history = model.fit(x_train, y_train, validation_split=0.3, epochs=40, batch_size=64, callbacks=[early_stop])
# Out:
# Epoch 1/40
# 30/30 [==============================] - 8s 74ms/step - loss: 0.0025 - root_mean_squared_error: 0.0504 - val_loss: 0.0451 - val_root_mean_squared_error: 0.2124
# Epoch 2/40
# 30/30 [==============================] - 1s 33ms/step - loss: 6.4696e-04 - root_mean_squared_error: 0.0254 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0751
# Epoch 3/40
# 30/30 [==============================] - 1s 28ms/step - loss: 4.5662e-04 - root_mean_squared_error: 0.0214 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0746
# Epoch 4/40
# 30/30 [==============================] - 1s 28ms/step - loss: 3.7925e-04 - root_mean_squared_error: 0.0195 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0768
# Epoch 5/40
# 30/30 [==============================] - 1s 25ms/step - loss: 3.2637e-04 - root_mean_squared_error: 0.0181 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0826
# Epoch 6/40
# 30/30 [==============================] - 1s 25ms/step - loss: 3.1057e-04 - root_mean_squared_error: 0.0176 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0857
# Epoch 7/40
# 30/30 [==============================] - 1s 26ms/step - loss: 2.8313e-04 - root_mean_squared_error: 0.0168 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0797
# Epoch 8/40
# 30/30 [==============================] - 1s 26ms/step - loss: 3.0078e-04 - root_mean_squared_error: 0.0173 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0945
# Epoch 8: early stopping

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'root_mean_squared_error', 'val_loss', 'val_root_mean_squared_error'])

# %%
fig = plt.figure(figsize=(12,7))
fig.add_subplot(121)

# Accuracy
plt.plot(history.epoch, history.history['root_mean_squared_error'], label = "rmse")
plt.plot(history.epoch, history.history['val_root_mean_squared_error'], label = "val_rmse")

plt.title("RMSE")
plt.xlabel("Epochs")
plt.ylabel("RMSE")
plt.grid(alpha=0.3)
plt.legend()


#Adding Subplot 1 (For Loss)
fig.add_subplot(122)

plt.plot(history.epoch, history.history['loss'], label="loss")
plt.plot(history.epoch, history.history['val_loss'], label="val_loss")

plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid(alpha=0.3)
plt.legend()

plt.show()

# %% [markdown]
# **Model Evaluation**

# %%
results = model.evaluate(x_test, y_test)
print("test loss , test rmse :", np.round(results, 4))
# Out:
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0053 - root_mean_squared_error: 0.0730
# test loss , test rmse : [0.0053 0.073 ]

# %%
y_pred = model.predict(x_test)
# Out:
# 21/21 [==============================] - 1s 6ms/step

# %% [markdown]
# **Evaluation metrics**

# %%
score = r2_score(y_test, y_pred)
print("The accuracy of our model is {}%".format(round(score, 2) *100))
# Out:
# The accuracy of our model is 54.0%

# %%
score = mean_absolute_error(y_test, y_pred)
print("The Mean Absolute Error of our Model is {}".format(round(score, 4)))
# Out:
# The Mean Absolute Error of our Model is 0.0655

# %%
score = mean_squared_error(y_test, y_pred)
print("The Mean Squared Error of our Model is {}".format(round(score, 4)))
# Out:
# The Mean Squared Error of our Model is 0.0053

# %%
score = np.sqrt(mean_squared_error(y_test, y_pred))
print("The Root Mean Squared Error of our Model is {}".format(round(score, 4)))
# Out:
# The Root Mean Squared Error of our Model is 0.073

# %% [markdown]
# **Hyperparameter Tuning Strategy**

# %%
def hyperparameter_tuning_strategy(config, x_train, y_train, x_test, y_test):
  additional_layer, neurons, batch_size, dropout = config
  possible_combinations = list(itertools.product(additional_layer, neurons, batch_size, dropout))
  print("*"*25)
  print(f"Possible No.of Combinations : {possible_combinations}")
  print("*"*25)
  hist = []
  for i in range(len(possible_combinations)):
    print("*"*25)
    print(f"Combination : {i+1}")
    print("*"*25)
    additional_layer, neurons, batch_size, dropout = possible_combinations[i]
    model = Sequential()
    model.add(LSTM(units=neurons, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2]), activation = "relu"))
    model.add(Dropout(dropout))
    if additional_layer:
      model.add(LSTM(units=neurons, return_sequences=True))
      model.add(Dropout(dropout))
    model.add(LSTM(units=neurons, return_sequences=False))
    model.add(Dropout(dropout))
    model.add(Dense(units=1, activation='linear'))
    model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
    early_stops = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
    file_path = 'best_model.h5'
    model_check = ModelCheckpoint(file_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)
    model.fit(x_train, y_train, validation_split=0.3, epochs=40, batch_size=batch_size, callbacks=[early_stop, model_check], verbose=0)
    train_loss, train_rmse = model.evaluate(x_train, y_train, verbose=0)
    test_loss, test_rmse = model.evaluate(x_test, y_test, verbose=0)
    hist.append(list((additional_layer, neurons, batch_size, dropout, train_loss, train_rmse, test_loss, test_rmse)))
    print(f"Combination : {i+1} -> {possible_combinations[i]} train_rmse : {train_rmse} test_rmse : {test_rmse}")
    print("*"*25)
    print("*"*25)
  return hist

# %%
config = [[False,True], [16, 32], [8, 16, 32], [0.2]]

hist = hyperparameter_tuning_strategy(config, x_train, y_train, x_test, y_test)
# Out:
# *************************
# Possible No.of Combinations : [(False, 16, 8, 0.2), (False, 16, 16, 0.2), (False, 16, 32, 0.2), (False, 32, 8, 0.2), (False, 32, 16, 0.2), (False, 32, 32, 0.2), (True, 16, 8, 0.2), (True, 16, 16, 0.2), (True, 16, 32, 0.2), (True, 32, 8, 0.2), (True, 32, 16, 0.2), (True, 32, 32, 0.2)]
# *************************
# *************************
# Combination : 1
# *************************
#
# Epoch 1: val_loss improved from inf to 0.00436, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 0.00436 to 0.00277, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.00277
#
# Epoch 4: val_loss did not improve from 0.00277
#
# Epoch 5: val_loss did not improve from 0.00277
#
# Epoch 6: val_loss did not improve from 0.00277
#
# Epoch 7: val_loss did not improve from 0.00277
# Epoch 7: early stopping
# Combination : 1 -> (False, 16, 8, 0.2) train_rmse : 0.036071307957172394 test_rmse : 0.0343945175409317
# *************************
# *************************
# *************************
# Combination : 2
# *************************
#
# Epoch 1: val_loss improved from inf to 0.00551, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.00551 to 0.00495, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.00495
#
# Epoch 4: val_loss did not improve from 0.00495
#
# Epoch 5: val_loss improved from 0.00495 to 0.00435, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.00435
#
# Epoch 7: val_loss did not improve from 0.00435
#
# Epoch 8: val_loss did not improve from 0.00435
#
# Epoch 9: val_loss did not improve from 0.00435
#
# Epoch 10: val_loss did not improve from 0.00435
# Epoch 10: early stopping
# Combination : 2 -> (False, 16, 16, 0.2) train_rmse : 0.04523855820298195 test_rmse : 0.05053051561117172
# *************************
# *************************
# *************************
# Combination : 3
# *************************
#
# Epoch 1: val_loss improved from inf to 0.01715, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.01715 to 0.00343, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.00343 to 0.00305, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.00305
#
# Epoch 5: val_loss improved from 0.00305 to 0.00265, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.00265
#
# Epoch 7: val_loss did not improve from 0.00265
#
# Epoch 8: val_loss did not improve from 0.00265
#
# Epoch 9: val_loss did not improve from 0.00265
#
# Epoch 10: val_loss did not improve from 0.00265
# Epoch 10: early stopping
# Combination : 3 -> (False, 16, 32, 0.2) train_rmse : 0.042215846478939056 test_rmse : 0.04839281737804413
# *************************
# *************************
# *************************
# Combination : 4
# *************************
#
# Epoch 1: val_loss improved from inf to 0.01434, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.01434 to 0.00900, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.00900
#
# Epoch 4: val_loss improved from 0.00900 to 0.00542, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.00542
#
# Epoch 6: val_loss did not improve from 0.00542
#
# Epoch 7: val_loss did not improve from 0.00542
#
# Epoch 8: val_loss did not improve from 0.00542
#
# Epoch 9: val_loss did not improve from 0.00542
# Epoch 9: early stopping
# Combination : 4 -> (False, 32, 8, 0.2) train_rmse : 0.050459813326597214 test_rmse : 0.04811675846576691
# *************************
# *************************
# *************************
# Combination : 5
# *************************
#
# Epoch 1: val_loss improved from inf to 0.00314, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.00314
#
# Epoch 3: val_loss did not improve from 0.00314
#
# Epoch 4: val_loss did not improve from 0.00314
#
# Epoch 5: val_loss did not improve from 0.00314
#
# Epoch 6: val_loss did not improve from 0.00314
# Epoch 6: early stopping
# Combination : 5 -> (False, 32, 16, 0.2) train_rmse : 0.04109371826052666 test_rmse : 0.045648135244846344
# *************************
# *************************
# *************************
# Combination : 6
# *************************
#
# Epoch 1: val_loss improved from inf to 0.07439, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.07439 to 0.04222, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.04222 to 0.03595, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 0.03595 to 0.03572, saving model to best_model.h5
#
# Epoch 5: val_loss improved from 0.03572 to 0.01637, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.01637
#
# Epoch 7: val_loss did not improve from 0.01637
#
# Epoch 8: val_loss did not improve from 0.01637
#
# Epoch 9: val_loss improved from 0.01637 to 0.01336, saving model to best_model.h5
#
# Epoch 10: val_loss improved from 0.01336 to 0.01097, saving model to best_model.h5
#
# Epoch 11: val_loss did not improve from 0.01097
#
# Epoch 12: val_loss improved from 0.01097 to 0.00768, saving model to best_model.h5
#
# Epoch 13: val_loss improved from 0.00768 to 0.00573, saving model to best_model.h5
#
# Epoch 14: val_loss did not improve from 0.00573
#
# Epoch 15: val_loss improved from 0.00573 to 0.00289, saving model to best_model.h5
#
# Epoch 16: val_loss improved from 0.00289 to 0.00248, saving model to best_model.h5
#
# Epoch 17: val_loss did not improve from 0.00248
#
# Epoch 18: val_loss did not improve from 0.00248
#
# Epoch 19: val_loss did not improve from 0.00248
#
# Epoch 20: val_loss did not improve from 0.00248
#
# Epoch 21: val_loss did not improve from 0.00248
# Epoch 21: early stopping
# Combination : 6 -> (False, 32, 32, 0.2) train_rmse : 0.06036626547574997 test_rmse : 0.0608140267431736
# *************************
# *************************
# *************************
# Combination : 7
# *************************
#
# Epoch 1: val_loss improved from inf to 0.01208, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.01208
#
# Epoch 3: val_loss did not improve from 0.01208
#
# Epoch 4: val_loss improved from 0.01208 to 0.00938, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.00938
#
# Epoch 6: val_loss did not improve from 0.00938
#
# Epoch 7: val_loss did not improve from 0.00938
#
# Epoch 8: val_loss did not improve from 0.00938
#
# Epoch 9: val_loss did not improve from 0.00938
# Epoch 9: early stopping
# Combination : 7 -> (True, 16, 8, 0.2) train_rmse : 0.10222511738538742 test_rmse : 0.10139469802379608
# *************************
# *************************
# *************************
# Combination : 8
# *************************
#
# Epoch 1: val_loss improved from inf to 0.01308, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.01308 to 0.01091, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.01091 to 0.00739, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 0.00739 to 0.00654, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.00654
#
# Epoch 6: val_loss improved from 0.00654 to 0.00409, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.00409
#
# Epoch 8: val_loss did not improve from 0.00409
#
# Epoch 9: val_loss did not improve from 0.00409
#
# Epoch 10: val_loss did not improve from 0.00409
#
# Epoch 11: val_loss did not improve from 0.00409
# Epoch 11: early stopping
# Combination : 8 -> (True, 16, 16, 0.2) train_rmse : 0.037334930151700974 test_rmse : 0.06106673181056976
# *************************
# *************************
# *************************
# Combination : 9
# *************************
#
# Epoch 1: val_loss improved from inf to 0.00409, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.00409 to 0.00392, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.00392
#
# Epoch 4: val_loss did not improve from 0.00392
#
# Epoch 5: val_loss did not improve from 0.00392
#
# Epoch 6: val_loss did not improve from 0.00392
#
# Epoch 7: val_loss did not improve from 0.00392
# Epoch 7: early stopping
# Combination : 9 -> (True, 16, 32, 0.2) train_rmse : 0.07512668520212173 test_rmse : 0.0814933329820633
# *************************
# *************************
# *************************
# Combination : 10
# *************************
#
# Epoch 1: val_loss improved from inf to 0.00632, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.00632
#
# Epoch 3: val_loss did not improve from 0.00632
#
# Epoch 4: val_loss did not improve from 0.00632
#
# Epoch 5: val_loss did not improve from 0.00632
#
# Epoch 6: val_loss did not improve from 0.00632
# Epoch 6: early stopping
# Combination : 10 -> (True, 32, 8, 0.2) train_rmse : 0.050930626690387726 test_rmse : 0.05495499446988106
# *************************
# *************************
# *************************
# Combination : 11
# *************************
#
# Epoch 1: val_loss improved from inf to 0.00446, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.00446
#
# Epoch 3: val_loss did not improve from 0.00446
#
# Epoch 4: val_loss improved from 0.00446 to 0.00428, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.00428
#
# Epoch 6: val_loss did not improve from 0.00428
#
# Epoch 7: val_loss did not improve from 0.00428
#
# Epoch 8: val_loss did not improve from 0.00428
#
# Epoch 9: val_loss did not improve from 0.00428
# Epoch 9: early stopping
# Combination : 11 -> (True, 32, 16, 0.2) train_rmse : 0.06262198090553284 test_rmse : 0.06532508134841919
# *************************
# *************************
# *************************
# Combination : 12
# *************************
#
# Epoch 1: val_loss improved from inf to 0.00993, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.00993
#
# Epoch 3: val_loss did not improve from 0.00993
#
# Epoch 4: val_loss did not improve from 0.00993
#
# Epoch 5: val_loss did not improve from 0.00993
#
# Epoch 6: val_loss did not improve from 0.00993
# Epoch 6: early stopping
# Combination : 12 -> (True, 32, 32, 0.2) train_rmse : 0.06754446029663086 test_rmse : 0.07174643129110336
# *************************
# *************************

# %%
hist = pd.DataFrame(hist, columns=["Additional Layer", "Neurons", "Batch Size", "Drop Out", "Train Loss", "Train RMSE", "Test Loss", "Test RMSE"])
hist = hist.sort_values(by=["Test RMSE"], ascending=True)
hist
# Out:
#     Additional Layer  Neurons  Batch Size  Drop Out  Train Loss  Train RMSE  \
# 0              False       16           8       0.2    0.001301    0.036071
# 4              False       32          16       0.2    0.001689    0.041094
# 3              False       32           8       0.2    0.002546    0.050460
# 2              False       16          32       0.2    0.001782    0.042216
# 1              False       16          16       0.2    0.002047    0.045239
# 9               True       32           8       0.2    0.002594    0.050931
# 5              False       32          32       0.2    0.003644    0.060366
# 7               True       16          16       0.2    0.001394    0.037335
# 10              True       32          16       0.2    0.003922    0.062622
# 11              True       32          32       0.2    0.004562    0.067544
# 8               True       16          32       0.2    0.005644    0.075127
# 6               True       16           8       0.2    0.010450    0.102225
#
#     Test Loss  Test RMSE
# 0    0.001183   0.034395
# 4    0.002084   0.045648
# 3    0.002315   0.048117
# 2    0.002342   0.048393
# 1    0.002553   0.050531
# 9    0.003020   0.054955
# 5    0.003698   0.060814
# 7    0.003729   0.061067
# 10   0.004267   0.065325
# 11   0.005148   0.071746
# 8    0.006641   0.081493
# 6    0.010281   0.101395

# %%
print("*"*25)
print(f"----Best Combination---- \n Additonal Layer = {hist.iloc[0,0]}\n Neurons = {hist.iloc[0,1]}\n Batch Size = {hist.iloc[0,2]}\n Drop Out = {hist.iloc[0,3]}\n")
print("*"*25)
print("*"*25)
before_rmse = np.round(results, 4)[1]
after_rmse = np.round(hist.iloc[0, -1], 4)
print(f'Results Before Tunning:\n Test Set RMSE: {before_rmse}\n')
print(f'Results After Tunning:\n Test Set RMSE: {after_rmse}\n')
print(f'{np.round((before_rmse-after_rmse)*100/before_rmse)}% Improvement')
# Out:
# *************************
# ----Best Combination----
#  Additonal Layer = False
#  Neurons = 16
#  Batch Size = 8
#  Drop Out = 0.2
#
# *************************
# *************************
# Results Before Tunning:
#  Test Set RMSE: 0.073
#
# Results After Tunning:
#  Test Set RMSE: 0.0344
#
# 53.0% Improvement

# %%
additional_layer, neurons, batch_size, dropout = list(hist.iloc[0, :-4])

# %% [markdown]
# **Best Model Training**

# %%
model = Sequential()
model.add(LSTM(units=neurons, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2]), activation = "relu"))
model.add(Dropout(dropout))

if additional_layer:
    model.add(LSTM(units=neurons, return_sequences=True))
    model.add(Dropout(dropout))

model.add(LSTM(units=neurons, return_sequences=False))
model.add(Dropout(dropout))
model.add(Dense(units=1, activation='linear'))
model.compile(optimizer='adam', loss='mse')

early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

file_path = 'best_model.h5'

model_check = ModelCheckpoint(file_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)

history = model.fit(x_train, y_train, validation_split=0.3, epochs=40, batch_size=batch_size, callbacks=[early_stop, model_check], verbose=0)
# Out:
# Epoch 1: val_loss improved from inf to 0.01632, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 0.01632 to 0.01288, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.01288 to 0.00714, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.00714
#
# Epoch 5: val_loss improved from 0.00714 to 0.00333, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.00333
#
# Epoch 7: val_loss did not improve from 0.00333
#
# Epoch 8: val_loss did not improve from 0.00333
#
# Epoch 9: val_loss improved from 0.00333 to 0.00183, saving model to best_model.h5
#
# Epoch 10: val_loss did not improve from 0.00183
#
# Epoch 11: val_loss did not improve from 0.00183
#
# Epoch 12: val_loss did not improve from 0.00183
#
# Epoch 13: val_loss did not improve from 0.00183
#
# Epoch 14: val_loss did not improve from 0.00183
# Epoch 14: early stopping

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.figure(figsize=(12,7))

plt.plot(history.epoch, history.history['loss'], label="loss")
plt.plot(history.epoch, history.history['val_loss'], label="val_loss")

plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid(alpha=0.3)
plt.legend()

plt.show()

# %% [markdown]
# **Best Model Evaluation**

# %%
results = model.evaluate(x_test, y_test)
print("test loss , test rmse :", np.round(results, 4))
# Out:
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0017
# test loss , test rmse : 0.0017

# %%
y_pred = model.predict(x_test)
# Out:
# 21/21 [==============================] - 1s 6ms/step

# %% [markdown]
# **Evaluation metrics - Best Model**

# %%
score = r2_score(y_test, y_pred)
print("The accuracy of our model is {}%".format(round(score, 2) *100))
# Out:
# The accuracy of our model is 85.0%

# %%
score = mean_absolute_error(y_test, y_pred)
print("The Mean Absolute Error of our Model is {}".format(round(score, 4)))
# Out:
# The Mean Absolute Error of our Model is 0.0345

# %%
score = mean_squared_error(y_test, y_pred)
print("The Mean Squared Error of our Model is {}".format(round(score, 4)))
# Out:
# The Mean Squared Error of our Model is 0.0017

# %%
score = np.sqrt(mean_squared_error(y_test, y_pred))
print("The Root Mean Squared Error of our Model is {}".format(round(score, 4)))
# Out:
# The Root Mean Squared Error of our Model is 0.0417

# %% [markdown]
# **Plot - Scaled Data - Closing Price vs Predicted Closing Price**

# %%
plt.figure(figsize=(16,8), dpi= 100, facecolor='w', edgecolor='k')

plt.plot(y_test, color='red', label = 'Closing Price')
plt.plot(y_pred, color='green', label = 'Predicted Closing Price')
plt.legend(loc='best')
plt.title("Scaled Data - Closing Price vs Predicted Closing Price - Test Dataset")
plt.show()

# %%
data_x.shape, data_y.shape
# Out:
# ((3332, 25, 2), (3332, 1))

# %%
pred_data_y = model.predict(data_x)
# Out:
# 105/105 [==============================] - 1s 6ms/step

# %% [markdown]
# **Plot - Scaled Data - Closing Price vs Predicted Closing Price - Overall Dataset**

# %%
plt.figure(figsize=(16,8), dpi= 100, facecolor='w', edgecolor='k')
plt.plot(data_y, color='red', label = 'Closing Price')
plt.plot(pred_data_y, color='green', label = 'Predicted Closing Price')
plt.legend(loc='best')
plt.title("Scaled Data - Closing Price vs Predicted Closing Price - Overall Dataset")
plt.show()

# %% [markdown]
# **Inverting the Min-Max Scaler - Reverting to Original Values**

# %%
new_data = [list((i[0],0)) for i in data_y]
data = scalar.inverse_transform(new_data)
overall_data = [i for i, j in data]

# %%
overall_data[:5]
# Out:
# [378.549011, 390.414001, 400.869995, 394.77301, 382.556]

# %%
new_data = [list((i[0],0)) for i in pred_data_y]
pred_data = scalar.inverse_transform(new_data)
pred_overall_data = [i for i, j in pred_data]

# %%
pred_overall_data[:5]
# Out:
# [336.4390566877894,
#  336.79453295836197,
#  337.75125616962754,
#  339.3185148964528,
#  341.16945172055705]

# %%
df = pd.DataFrame(overall_data, columns=['Close'])

# %%
df['Date']=list(dataframe.iloc[25:,0])

# %%
df['Pred Close'] = pred_overall_data

# %%
df.head()
# Out:
#         Close       Date  Pred Close
# 0  378.549011 2014-10-12  336.439057
# 1  390.414001 2014-10-13  336.794533
# 2  400.869995 2014-10-14  337.751256
# 3  394.773010 2014-10-15  339.318515
# 4  382.556000 2014-10-16  341.169452

# %% [markdown]
# **Plot - Original Closing Price vs Predicted Closing Price - Overall Dataset - Inverted to Original Values**

# %%
plt.figure(figsize=(14,6), dpi= 100, facecolor='w', edgecolor='k')

plt.plot(df['Date'], df['Close'], color='red', label = 'Closing Price')
plt.plot(df['Date'], df['Pred Close'], color='blue', label = 'Predicted Closing Price')
plt.xlabel('Date')
plt.ylabel('USD')
plt.title("Original Closing Price vs Predicted Closing Price - Overall Dataset")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Results - Conclusion**

# %% [markdown]
# **From the above plot we can see our model is able to predict the general trend
# of moving up and down but falls short when predicting the the accurate high and
# lows**
